# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI(
    api_key=os.getenv("FOUNDRY_OPENAI_API_KEY"),
    base_url="https://msf-makbs-aifoundry.openai.azure.com/openai/v1"
)

# %%
completion = client.chat.completions.create(
    model="gpt-5-nano",  # Required: your deployment name
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Azure AI ってなに?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 「Azure AI」 とは、Microsoft Azure 上の AI 関連サービスの総称です。クラウド上で AI を活用したアプリを作ったり、AI 機能を自分のサービスに組み込んだりするためのツール群を指します。
#
# 主な構成例
# - Azure Cognitive Services（認知サービス）: 事前学習済みの API 群。Vision（画像処理）、Speech（音声認識・合成）、Language（言語理解・要約・分析）、Decision（意思決定支援）、Search など。
# - Azure OpenAI Service: OpenAI の大規模言語モデル（例: GPT-4 など）を Azure 上で利用・管理・デプロイするサービス。
# - Azure Machine Learning: 自社モデルの開発・トレーニング・デプロイ・MLOps（運用型機械学習）を行う総合プラットフォーム。
# - Azure Bot Service / Bot Framework: チャットボットの開発・デプロイ。
# - その他連携領域: Azure Cognitive Search（検索機能を強化）、データ基盤（Azure Data Lake, Synapse）との統合など。
#
# 特徴
# - すぐ使える AI API から、独自モデルの開発・運用まで幅広くサポート。
# - コードを書かずに使える API（Cognitive Services）と、カスタムモデルを作って運用する ML/SaaS 的な選択肢がある。
# - セキュリティ・ガバナンス、Responsible AI（倫理・透明性・リスク管理）機能も提供。
# - 料金はサービスごとに従量課金。無料枠や試用オプションがある場合も。
#
# 使い方の流れ（ざっくり）
# 1) Azure アカウントを作成
# 2) 使いたいサービスを選ぶ（例: 画像なら Computer Vision、要約なら Language、独自モデル運用なら Azure ML など）
# 3) API キーやエンドポイントを取得して、アプリから呼び出す
# 4) 必要に応じてデータ連携（Azure Data Lake / Synapse など）やセキュリティ設定を整える
#
# もし具体的な用途があるなら、それに合わせた始め方（どのサービスを使うべきか、サンプルの進め方）を詳しくご案内します。たとえば「顧客サポートの自動応答を作りたい」「社内ドキュメントを自動で要約したい」など教えてください。
