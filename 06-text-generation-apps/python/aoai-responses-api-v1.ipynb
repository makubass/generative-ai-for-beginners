# %% [markdown]
# ### Azure OpenAI を Response API V1（OpenAI SDK）でリクエスト

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI(
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    # base_url="https://<YOUR RESOURCE NAME>.openai.azure.com/openai/v1",
    base_url="https://mkbs-aifoundry-resource.openai.azure.com//openai/v1/"
)

# %%
response = client.responses.create(
    model="gpt-4.1-nano",  # Required: your deployment name
    instructions="You are a helpful assistant.",
    input="Azure AI ってなに?",
)

print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "resp_0dcad6358f15ad8c00692c5d8fa68481959ab558bfe98c6624",
#   "created_at": 1764515215.0,
#   "error": null,
#   "incomplete_details": null,
#   "instructions": "You are a helpful assistant.",
#   "metadata": {},
#   "model": "gpt-4.1-nano",
#   "object": "response",
#   "output": [
#     {
#       "id": "msg_0dcad6358f15ad8c00692c5d902ee48195aa1b2a62dae29210",
#       "content": [
#         {
#           "annotations": [],
#           "text": "Azure AIは、MicrosoftのクラウドプラットフォームであるAzureが提供する人工知能（AI）に関連するサービスやツールの総称です。これには、機械学習、自然言語処理、コンピュータビジョンなどさまざまなAI技術を活用できるサービスが含まれます。\n\n具体的には、以下のようなAzure AIのサービスがあります：\n\n- **Azure Cognitive Services（Azure認知サービス）**：画像認識、音声認識、自然言語理解、翻訳など、事前に訓練されたAIモデルを容易に利用できるサービス。\n- **Azure Machine Learning**：カスタムの機械学習モデルを構築、訓練、デプロイできるプラットフォーム。\n- **Azure Bot Services**：チャットボットや仮想アシスタントの作成と展開を支援。\n- **Azure Form Recognizer**や**Speech Services**などの特定のAIサービスも含まれます。\n\nこれらを利用することで、開発者や企業は高度なAI機能を自身のアプリケーションやシステムに簡単に組み込むことができ、多様なビジネス課題の解決や新しい体験の提供に役立てることができます。\n\nもしもっと詳しい情報が知りたい、特定のサービスについて質問があれば教えてください！",
#           "type": "output_text",
#           "logprobs": []
#         }
#       ],
#       "role": "assistant",
#       "status": "completed",
#       "type": "message"
#     }
#   ],
#   "parallel_tool_calls": true,
#   "temperature": 1.0,
#   "tool_choice": "auto",
#   "tools": [],
#   "top_p": 1.0,
#   "background": false,
#   "conversation": null,
#   "max_output_tokens": null,
#   "max_tool_calls": null,
#   "previous_response_id": null,
#   "prompt": null,
#   "prompt_cache_key": null,
#   "prompt_cache_retention": null,
#   "reasoning": {
#     "effort": null,
#     "generate_summary": null,
#     "summary": null
#   },
#   "safety_identifier": null,
#   "service_tier": "default",
#   "status": "completed",
#   "text": {
#     "format": {
#       "type": "text"
#     },
#     "verbosity": "medium"
#   },
#   "top_logprobs": 0,
#   "truncation": "disabled",
#   "usage": {
#     "input_tokens": 24,
#     "input_tokens_details": {
#       "cached_tokens": 0
#     },
#     "output_tokens": 323,
#     "output_tokens_details": {
#       "reasoning_tokens": 0
#     },
#     "total_tokens": 347
#   },
#   "user": null,
#   "content_filters": null,
#   "store": true
# }
