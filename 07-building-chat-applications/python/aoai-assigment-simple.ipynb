# %% [markdown]
# ### AI Foundry の AOAIサービスに対してresponses API(V1)でリクエストに修正

# %%
import os
from openai import OpenAI

API_KEY = os.getenv("AZURE_OPENAI_API_KEY","").strip()
assert API_KEY, "ERROR: Azure OpenAI Key is missing"

RESOURCE_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT_V1","").strip()
assert RESOURCE_ENDPOINT, "ERROR: Azure OpenAI Endpoint is missing"

deployment = os.getenv("AZURE_OPENAI_DEPLOYMENT", "").strip()
assert deployment, "ERROR: Azure OpenAI Deployment name is missing"

client = OpenAI(
    api_key=API_KEY,
    base_url=RESOURCE_ENDPOINT
)

# %% [markdown]
# ##### １回目の応答

# %%
# Create your first prompt
first_text_prompt = "日本で一番大きい湖は？"

first_response = client.responses.create(
  model=deployment,
  instructions="You are a helpful assistant.",
  input=first_text_prompt
)

print(first_response.output_text)
print(first_response.id)
# Out:
# 日本で一番大きい湖は琵琶湖（びわこ）です。面積は約674平方キロメートルで、日本最大の淡水湖です。滋賀県に位置し、観光やレクリエーションの場としても人気があります。
# resp_0fd232ab0ae4050500692d9e9daf708190997c150ee1f48a15

# %% [markdown]
# ##### ２回目の応答

# %%
second_text_prompt = "２番目は？"

seconde_response = client.responses.create(
    model=deployment,
    previous_response_id=first_response.id,
    input=second_text_prompt
)
print(seconde_response.output_text)
print(seconde_response.id)
# Out:
# 日本で二番に大きい湖は霞ヶ浦（かすみがうら）です。面積は約212平方キロメートルで、茨城県と千葉県にまたがっています。霞ヶ浦も淡水湖で、釣りや水上スポーツなどのレクリエーション活動が盛んです。
# resp_0fd232ab0ae4050500692da02c63ec819092c47028f4550f4a

# %%
text_prompt_third = "それぞれについて名産や盛んなレクリエーションをあげてください？"

third_response = client.responses.create(
    model=deployment,
    previous_response_id=seconde_response.id,
    input=text_prompt_third
)
print(third_response.output_text)
print(third_response.id)
# Out:
# もちろんです。以下に琵琶湖と霞ヶ浦の名産品や盛んなレクリエーションを紹介します。
#
# ### 琵琶湖（びわこ）
# **名産品**
# - **魚介類**：琵琶湖は淡水魚の宝庫で、特に**ビワコオオナマズ**や**ブラックバス**、**ワカサギ**、**フナ**などが有名です。
# - **近江牛（おうみぎゅう）**：滋賀県全体の特産ですが、琵琶湖周辺で育てられる高級牛肉です。
# - **近江米**：滋賀県は米も名産で、琵琶湖の伏流水を利用した良質な米が生産されています。
#
# **盛んなレクリエーション**
# - **釣り**：ブラックバスやワカサギ釣りが非常に人気です。
# - **水上スポーツ**：カヌー、ウィンドサーフィン、スワップボートなど。
# - **湖畔散策**：琵琶湖舟運や、比叡山と合わせた観光コース。
# - **夏の花火大会**：大規模な湖上花火も行われます。
#
# ---
#
# ### 霞ヶ浦（かすみがうら）
# **名産品**
# - **シジミ**：霞ヶ浦はシジミ漁が盛んで、新鮮なシジミは味噌汁や佃煮に利用されます。
# - **霞ヶ浦の米**：肥沃な土壌を生かした米も名産です。
# - **野菜類**：特に季節の野菜や果物も豊富です。
#
# **盛んなレクリエーション**
# - **釣り**：ブラックバスやナマズ、ブルーギルなど、多種多様な魚釣りが楽しめます。
# - **水上レジャー**：カヌーやスタンドアップパドルボードなど。
# - **サイクリング**：湖周辺に整備されたサイクリングロードがあり、景色を楽しみながら自転車で巡ることができます。
# - **観光クルーズ**：霞ヶ浦の周囲をめぐる遊覧船も運航されています。
#
# 何か他に詳しく知りたいことがあれば教えてください！
# resp_0fd232ab0ae4050500692da10d15c881908e6837dbc221662b
